# %%
import gymnasium as gym
import panda_gym
from stable_baselines3 import DDPG
from stable_baselines3.her import HerReplayBuffer
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from stable_baselines3.common.callbacks import EvalCallback

# %%
# Training environment
train_env = gym.make("PandaPickAndPlaceDense-v3")  # Dense reward
train_env = Monitor(train_env)
train_env = DummyVecEnv([lambda: train_env])
train_env = VecMonitor(train_env)

# Evaluation environment
eval_env = gym.make("PandaPickAndPlaceDense-v3")
eval_env = Monitor(eval_env)
eval_env = DummyVecEnv([lambda: eval_env])
eval_env = VecMonitor(eval_env)
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# /home/kamal/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/vec_monitor.py:44: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(

# %%
model = DDPG(
    policy="MultiInputPolicy",              # Dict observation
    env=train_env,
    replay_buffer_class=HerReplayBuffer,    # HER
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future"
    ),
    verbose=1,
    tensorboard_log="./ddpg_her_dense_no_flattensorboard/"
)
# Out:
# Using cuda device

# %%
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./ddpg_her_dense_no_flat_best_model/",
    log_path="./ddpg_her_dense_no_flat_logs/",
    eval_freq=5000,
    deterministic=True,
    render=False
)

model.learn(total_timesteps=300_000, callback=eval_callback)
# Out:
# Logging to ./ddpg_her_dense_no_flattensorboard/DDPG_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.8     |
# |    ep_rew_mean     | -10.3    |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 170      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 151      |
# | train/             |          |
# |    actor_loss      | 0.0351   |
# |    critic_loss     | 0.0044   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 50       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.9     |
# |    ep_rew_mean     | -10.6    |
# |    success_rate    | 0.125    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 95       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 351      |
# | train/             |          |
# |    actor_loss      | 0.0239   |
# |    critic_loss     | 0.000566 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 250      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.9     |
# |    ep_rew_mean     | -9.98    |
# |    success_rate    | 0.0833   |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 84       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 551      |
# | train/             |          |
# |    actor_loss      | 0.0511   |
# |    critic_loss     | 0.000223 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 450      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.9     |
# |    ep_rew_mean     | -10.3    |
# |    success_rate    | 0.0625   |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 80       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 751      |
# | train/             |          |
# |    actor_loss      | 0.0424   |
# |    critic_loss     | 0.000197 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 650      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -10.4    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 78       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 951      |
# | train/             |          |
# |    actor_loss      | 0.00317  |
# |    critic_loss     | 0.000464 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 850      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -10.3    |
# |    success_rate    | 0.0417   |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 76       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1151     |
# | train/             |          |
# |    actor_loss      | -0.0088  |
# |    critic_loss     | 0.000305 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1050     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.2     |
# |    ep_rew_mean     | -10.3    |
# |    success_rate    | 0.0357   |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 74       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1351     |
# | train/             |          |
# |    actor_loss      | 0.000558 |
# |    critic_loss     | 0.000386 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1250     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -10.3    |
# |    success_rate    | 0.0312   |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 74       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1551     |
# | train/             |          |
# |    actor_loss      | 0.00522  |
# |    critic_loss     | 0.000329 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1450     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -10.2    |
# |    success_rate    | 0.0278   |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 73       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1751     |
# | train/             |          |
# |    actor_loss      | 0.00257  |
# |    critic_loss     | 0.000411 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1650     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.8     |
# |    ep_rew_mean     | -10.2    |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 73       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1951     |
# | train/             |          |
# |    actor_loss      | 0.0229   |
# |    critic_loss     | 0.000446 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1850     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.9     |
# |    ep_rew_mean     | -10.2    |
# |    success_rate    | 0.0227   |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 73       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 2151     |
# | train/             |          |
# |    actor_loss      | 0.0268   |
# |    critic_loss     | 0.000949 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2050     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -10.1    |
# |    success_rate    | 0.0208   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 72       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2351     |
# | train/             |          |
# |    actor_loss      | 0.000784 |
# |    critic_loss     | 0.000777 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2250     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | -9.99    |
# |    success_rate    | 0.0192   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 72       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 2551     |
# | train/             |          |
# |    actor_loss      | -0.0202  |
# |    critic_loss     | 0.000862 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2450     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | -9.76    |
# |    success_rate    | 0.0179   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 72       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2751     |
# | train/             |          |
# |    actor_loss      | 0.0305   |
# |    critic_loss     | 0.000583 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2650     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.2     |
# |    ep_rew_mean     | -9.87    |
# |    success_rate    | 0.0167   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 71       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 2951     |
# | train/             |          |
# |    actor_loss      | 0.0562   |
# |    critic_loss     | 0.000453 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2850     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.71    |
# |    success_rate    | 0.0312   |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 71       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 3102     |
# | train/             |          |
# |    actor_loss      | 0.0153   |
# |    critic_loss     | 0.0011   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3001     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -9.76    |
# |    success_rate    | 0.0294   |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 71       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 3302     |
# | train/             |          |
# |    actor_loss      | 0.0868   |
# |    critic_loss     | 0.0004   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3201     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -9.84    |
# |    success_rate    | 0.0278   |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 71       |
# |    time_elapsed    | 49       |
# |    total_timesteps | 3502     |
# | train/             |          |
# |    actor_loss      | 0.096    |
# |    critic_loss     | 0.000505 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3401     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.7     |
# |    ep_rew_mean     | -9.84    |
# |    success_rate    | 0.0263   |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 70       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 3702     |
# | train/             |          |
# |    actor_loss      | 0.155    |
# |    critic_loss     | 0.000394 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3601     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.2     |
# |    ep_rew_mean     | -9.74    |
# |    success_rate    | 0.0375   |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 71       |
# |    time_elapsed    | 54       |
# |    total_timesteps | 3853     |
# | train/             |          |
# |    actor_loss      | 0.171    |
# |    critic_loss     | 0.000669 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3752     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.2     |
# |    ep_rew_mean     | -9.61    |
# |    success_rate    | 0.0357   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 70       |
# |    time_elapsed    | 57       |
# |    total_timesteps | 4053     |
# | train/             |          |
# |    actor_loss      | 0.114    |
# |    critic_loss     | 0.000824 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3952     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.3     |
# |    ep_rew_mean     | -9.58    |
# |    success_rate    | 0.0341   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 70       |
# |    time_elapsed    | 60       |
# |    total_timesteps | 4253     |
# | train/             |          |
# |    actor_loss      | 0.105    |
# |    critic_loss     | 0.00149  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4152     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.4     |
# |    ep_rew_mean     | -9.51    |
# |    success_rate    | 0.0326   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 70       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 4453     |
# | train/             |          |
# |    actor_loss      | 0.141    |
# |    critic_loss     | 0.000998 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -9.24    |
# |    success_rate    | 0.0417   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 70       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 4604     |
# | train/             |          |
# |    actor_loss      | 0.103    |
# |    critic_loss     | 0.00284  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4503     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -9.29    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 70       |
# |    time_elapsed    | 68       |
# |    total_timesteps | 4804     |
# | train/             |          |
# |    actor_loss      | 0.144    |
# |    critic_loss     | 0.00185  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4703     |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=-10.21 +/- 3.63
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | 0.162    |
# |    critic_loss     | 0.000474 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4899     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.23    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 69       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 5004     |
# | train/             |          |
# |    actor_loss      | 0.2      |
# |    critic_loss     | 0.000719 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4903     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.1     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 69       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 5204     |
# | train/             |          |
# |    actor_loss      | 0.213    |
# |    critic_loss     | 0.000879 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5103     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -9.08    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 69       |
# |    time_elapsed    | 77       |
# |    total_timesteps | 5355     |
# | train/             |          |
# |    actor_loss      | 0.234    |
# |    critic_loss     | 0.000865 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5254     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -8.98    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 69       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 5555     |
# | train/             |          |
# |    actor_loss      | 0.225    |
# |    critic_loss     | 0.000643 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5454     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -8.94    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 69       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 5755     |
# | train/             |          |
# |    actor_loss      | 0.224    |
# |    critic_loss     | 0.00124  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5654     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -9.03    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 69       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 5955     |
# | train/             |          |
# |    actor_loss      | 0.286    |
# |    critic_loss     | 0.00147  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5854     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -8.96    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 69       |
# |    time_elapsed    | 88       |
# |    total_timesteps | 6155     |
# | train/             |          |
# |    actor_loss      | 0.269    |
# |    critic_loss     | 0.0018   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -8.9     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 69       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 6306     |
# | train/             |          |
# |    actor_loss      | 0.246    |
# |    critic_loss     | 0.00164  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6205     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -8.88    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 69       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 6506     |
# | train/             |          |
# |    actor_loss      | 0.293    |
# |    critic_loss     | 0.00176  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6405     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -8.78    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 69       |
# |    time_elapsed    | 96       |
# |    total_timesteps | 6706     |
# | train/             |          |
# |    actor_loss      | 0.229    |
# |    critic_loss     | 0.000862 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6605     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -8.72    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 69       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 6906     |
# | train/             |          |
# |    actor_loss      | 0.225    |
# |    critic_loss     | 0.00122  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6805     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -8.67    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 69       |
# |    time_elapsed    | 101      |
# |    total_timesteps | 7057     |
# | train/             |          |
# |    actor_loss      | 0.283    |
# |    critic_loss     | 0.0012   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6956     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -9.09    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 69       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 7257     |
# | train/             |          |
# |    actor_loss      | 0.393    |
# |    critic_loss     | 0.00972  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7156     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -9.16    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 69       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 7457     |
# | train/             |          |
# |    actor_loss      | 0.244    |
# |    critic_loss     | 0.00365  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7356     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -9.04    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 68       |
# |    time_elapsed    | 110      |
# |    total_timesteps | 7657     |
# | train/             |          |
# |    actor_loss      | 0.413    |
# |    critic_loss     | 0.00185  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7556     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -9.24    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 69       |
# |    time_elapsed    | 113      |
# |    total_timesteps | 7857     |
# | train/             |          |
# |    actor_loss      | 0.333    |
# |    critic_loss     | 0.00262  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7756     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -9.23    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 69       |
# |    time_elapsed    | 116      |
# |    total_timesteps | 8057     |
# | train/             |          |
# |    actor_loss      | 0.291    |
# |    critic_loss     | 0.00144  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7956     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -9.21    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 69       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 8257     |
# | train/             |          |
# |    actor_loss      | 0.314    |
# |    critic_loss     | 0.00261  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8156     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -9.06    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 69       |
# |    time_elapsed    | 121      |
# |    total_timesteps | 8457     |
# | train/             |          |
# |    actor_loss      | 0.347    |
# |    critic_loss     | 0.00244  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8356     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -9.11    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 69       |
# |    time_elapsed    | 124      |
# |    total_timesteps | 8657     |
# | train/             |          |
# |    actor_loss      | 0.482    |
# |    critic_loss     | 0.00128  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8556     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -9.48    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 69       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 8857     |
# | train/             |          |
# |    actor_loss      | 0.324    |
# |    critic_loss     | 0.00186  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8756     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -9.44    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 69       |
# |    time_elapsed    | 130      |
# |    total_timesteps | 9057     |
# | train/             |          |
# |    actor_loss      | 0.508    |
# |    critic_loss     | 0.00448  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8956     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -9.63    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 69       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 9257     |
# | train/             |          |
# |    actor_loss      | 0.447    |
# |    critic_loss     | 0.00189  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9156     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.96    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 69       |
# |    time_elapsed    | 136      |
# |    total_timesteps | 9457     |
# | train/             |          |
# |    actor_loss      | 0.33     |
# |    critic_loss     | 0.00155  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9356     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.87    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 69       |
# |    time_elapsed    | 139      |
# |    total_timesteps | 9657     |
# | train/             |          |
# |    actor_loss      | 0.296    |
# |    critic_loss     | 0.000646 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9556     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.88    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 69       |
# |    time_elapsed    | 141      |
# |    total_timesteps | 9857     |
# | train/             |          |
# |    actor_loss      | 0.409    |
# |    critic_loss     | 0.00162  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9756     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-8.46 +/- 2.52
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -8.46    |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 0.499    |
# |    critic_loss     | 0.0169   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9899     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.9     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 69       |
# |    time_elapsed    | 145      |
# |    total_timesteps | 10057    |
# | train/             |          |
# |    actor_loss      | 0.442    |
# |    critic_loss     | 0.0058   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9956     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -9.93    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 69       |
# |    time_elapsed    | 147      |
# |    total_timesteps | 10257    |
# | train/             |          |
# |    actor_loss      | 0.327    |
# |    critic_loss     | 0.00458  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10156    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -9.96    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 69       |
# |    time_elapsed    | 150      |
# |    total_timesteps | 10457    |
# | train/             |          |
# |    actor_loss      | 0.458    |
# |    critic_loss     | 0.0013   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10356    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -9.92    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 69       |
# |    time_elapsed    | 153      |
# |    total_timesteps | 10657    |
# | train/             |          |
# |    actor_loss      | 0.513    |
# |    critic_loss     | 0.00393  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10556    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -9.88    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 69       |
# |    time_elapsed    | 155      |
# |    total_timesteps | 10857    |
# | train/             |          |
# |    actor_loss      | 0.264    |
# |    critic_loss     | 0.00161  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10756    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.83    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 69       |
# |    time_elapsed    | 157      |
# |    total_timesteps | 11008    |
# | train/             |          |
# |    actor_loss      | 0.508    |
# |    critic_loss     | 0.00448  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -10.1    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 69       |
# |    time_elapsed    | 160      |
# |    total_timesteps | 11208    |
# | train/             |          |
# |    actor_loss      | 0.448    |
# |    critic_loss     | 0.00631  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11107    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -10.1    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 70       |
# |    time_elapsed    | 162      |
# |    total_timesteps | 11408    |
# | train/             |          |
# |    actor_loss      | 0.5      |
# |    critic_loss     | 0.00795  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11307    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -10.2    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 70       |
# |    time_elapsed    | 165      |
# |    total_timesteps | 11608    |
# | train/             |          |
# |    actor_loss      | 0.474    |
# |    critic_loss     | 0.00426  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11507    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -10.1    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 70       |
# |    time_elapsed    | 167      |
# |    total_timesteps | 11808    |
# | train/             |          |
# |    actor_loss      | 0.433    |
# |    critic_loss     | 0.00328  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11707    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -10.1    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 70       |
# |    time_elapsed    | 169      |
# |    total_timesteps | 11959    |
# | train/             |          |
# |    actor_loss      | 0.535    |
# |    critic_loss     | 0.00191  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11858    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -9.81    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 70       |
# |    time_elapsed    | 172      |
# |    total_timesteps | 12159    |
# | train/             |          |
# |    actor_loss      | 0.488    |
# |    critic_loss     | 0.00147  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12058    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -9.88    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 70       |
# |    time_elapsed    | 174      |
# |    total_timesteps | 12359    |
# | train/             |          |
# |    actor_loss      | 0.46     |
# |    critic_loss     | 0.00176  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12258    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -10.1    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 70       |
# |    time_elapsed    | 177      |
# |    total_timesteps | 12559    |
# | train/             |          |
# |    actor_loss      | 0.427    |
# |    critic_loss     | 0.00557  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12458    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -9.96    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 71       |
# |    time_elapsed    | 179      |
# |    total_timesteps | 12759    |
# | train/             |          |
# |    actor_loss      | 0.543    |
# |    critic_loss     | 0.00738  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12658    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -10      |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 71       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 12910    |
# | train/             |          |
# |    actor_loss      | 0.615    |
# |    critic_loss     | 0.00437  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12809    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.97    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 71       |
# |    time_elapsed    | 183      |
# |    total_timesteps | 13110    |
# | train/             |          |
# |    actor_loss      | 0.607    |
# |    critic_loss     | 0.0057   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13009    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -10.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 71       |
# |    time_elapsed    | 186      |
# |    total_timesteps | 13310    |
# | train/             |          |
# |    actor_loss      | 0.603    |
# |    critic_loss     | 0.00439  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13209    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -10      |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 71       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 13510    |
# | train/             |          |
# |    actor_loss      | 0.534    |
# |    critic_loss     | 0.00242  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13409    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.8     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 71       |
# |    time_elapsed    | 191      |
# |    total_timesteps | 13710    |
# | train/             |          |
# |    actor_loss      | 0.573    |
# |    critic_loss     | 0.00273  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13609    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.77    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 71       |
# |    time_elapsed    | 194      |
# |    total_timesteps | 13910    |
# | train/             |          |
# |    actor_loss      | 0.344    |
# |    critic_loss     | 0.00562  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13809    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.76    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 71       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 14110    |
# | train/             |          |
# |    actor_loss      | 0.46     |
# |    critic_loss     | 0.00372  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14009    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.75    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 71       |
# |    time_elapsed    | 199      |
# |    total_timesteps | 14310    |
# | train/             |          |
# |    actor_loss      | 0.545    |
# |    critic_loss     | 0.0161   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14209    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.78    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 71       |
# |    time_elapsed    | 201      |
# |    total_timesteps | 14510    |
# | train/             |          |
# |    actor_loss      | 0.387    |
# |    critic_loss     | 0.00223  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14409    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.75    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 72       |
# |    time_elapsed    | 204      |
# |    total_timesteps | 14710    |
# | train/             |          |
# |    actor_loss      | 0.554    |
# |    critic_loss     | 0.00516  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14609    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.7     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 72       |
# |    time_elapsed    | 206      |
# |    total_timesteps | 14910    |
# | train/             |          |
# |    actor_loss      | 0.363    |
# |    critic_loss     | 0.00457  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14809    |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=-10.00 +/- 1.67
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | 0.538    |
# |    critic_loss     | 0.00264  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.75    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 72       |
# |    time_elapsed    | 209      |
# |    total_timesteps | 15110    |
# | train/             |          |
# |    actor_loss      | 0.529    |
# |    critic_loss     | 0.00576  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15009    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.68    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 72       |
# |    time_elapsed    | 212      |
# |    total_timesteps | 15310    |
# | train/             |          |
# |    actor_loss      | 0.352    |
# |    critic_loss     | 0.0119   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15209    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.68    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 72       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 15510    |
# | train/             |          |
# |    actor_loss      | 0.574    |
# |    critic_loss     | 0.0087   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15409    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -9.57    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 72       |
# |    time_elapsed    | 216      |
# |    total_timesteps | 15710    |
# | train/             |          |
# |    actor_loss      | 0.573    |
# |    critic_loss     | 0.00638  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15609    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -9.95    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 72       |
# |    time_elapsed    | 219      |
# |    total_timesteps | 15910    |
# | train/             |          |
# |    actor_loss      | 0.433    |
# |    critic_loss     | 0.0135   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15809    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.7     |
# |    ep_rew_mean     | -9.59    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 72       |
# |    time_elapsed    | 221      |
# |    total_timesteps | 16076    |
# | train/             |          |
# |    actor_loss      | 0.356    |
# |    critic_loss     | 0.0102   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15975    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.7     |
# |    ep_rew_mean     | -9.56    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 72       |
# |    time_elapsed    | 223      |
# |    total_timesteps | 16276    |
# | train/             |          |
# |    actor_loss      | 0.511    |
# |    critic_loss     | 0.0543   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16175    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.7     |
# |    ep_rew_mean     | -9.49    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 72       |
# |    time_elapsed    | 226      |
# |    total_timesteps | 16476    |
# | train/             |          |
# |    actor_loss      | 0.568    |
# |    critic_loss     | 0.00444  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16375    |
# ---------------------------------
# ...
# | train/             |          |
# |    actor_loss      | -3.77    |
# |    critic_loss     | 0.0826   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294864   |
# ---------------------------------
# Eval num_timesteps=295000, episode_reward=-10.75 +/- 1.89
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -10.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 295000   |
# | train/             |          |
# |    actor_loss      | -3.57    |
# |    critic_loss     | 0.291    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -8.57    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 6096     |
# |    fps             | 28       |
# |    time_elapsed    | 10196    |
# |    total_timesteps | 295116   |
# | train/             |          |
# |    actor_loss      | -3.5     |
# |    critic_loss     | 0.0415   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295015   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -8.51    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 6100     |
# |    fps             | 28       |
# |    time_elapsed    | 10200    |
# |    total_timesteps | 295218   |
# | train/             |          |
# |    actor_loss      | -3.69    |
# |    critic_loss     | 0.057    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295117   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -8.56    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 6104     |
# |    fps             | 28       |
# |    time_elapsed    | 10207    |
# |    total_timesteps | 295418   |
# | train/             |          |
# |    actor_loss      | -4.31    |
# |    critic_loss     | 0.203    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295317   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -8.62    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 6108     |
# |    fps             | 28       |
# |    time_elapsed    | 10214    |
# |    total_timesteps | 295618   |
# | train/             |          |
# |    actor_loss      | -3.05    |
# |    critic_loss     | 0.341    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295517   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -8.53    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 6112     |
# |    fps             | 28       |
# |    time_elapsed    | 10221    |
# |    total_timesteps | 295818   |
# | train/             |          |
# |    actor_loss      | -3.7     |
# |    critic_loss     | 0.0943   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295717   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -8.76    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 6116     |
# |    fps             | 28       |
# |    time_elapsed    | 10228    |
# |    total_timesteps | 296018   |
# | train/             |          |
# |    actor_loss      | -3.4     |
# |    critic_loss     | 0.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295917   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -8.75    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 6120     |
# |    fps             | 28       |
# |    time_elapsed    | 10235    |
# |    total_timesteps | 296218   |
# | train/             |          |
# |    actor_loss      | -2.92    |
# |    critic_loss     | 0.275    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296117   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -8.88    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 6124     |
# |    fps             | 28       |
# |    time_elapsed    | 10243    |
# |    total_timesteps | 296418   |
# | train/             |          |
# |    actor_loss      | -3.61    |
# |    critic_loss     | 0.109    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296317   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -8.9     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 6128     |
# |    fps             | 28       |
# |    time_elapsed    | 10248    |
# |    total_timesteps | 296569   |
# | train/             |          |
# |    actor_loss      | -3.83    |
# |    critic_loss     | 0.062    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296468   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | -8.68    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 6132     |
# |    fps             | 28       |
# |    time_elapsed    | 10252    |
# |    total_timesteps | 296671   |
# | train/             |          |
# |    actor_loss      | -3.69    |
# |    critic_loss     | 0.354    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296570   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.1     |
# |    ep_rew_mean     | -8.6     |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 6136     |
# |    fps             | 28       |
# |    time_elapsed    | 10256    |
# |    total_timesteps | 296778   |
# | train/             |          |
# |    actor_loss      | -3.51    |
# |    critic_loss     | 0.274    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296677   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.1     |
# |    ep_rew_mean     | -8.68    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 6140     |
# |    fps             | 28       |
# |    time_elapsed    | 10263    |
# |    total_timesteps | 296978   |
# | train/             |          |
# |    actor_loss      | -3.52    |
# |    critic_loss     | 0.223    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296877   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | -8.97    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 6144     |
# |    fps             | 28       |
# |    time_elapsed    | 10270    |
# |    total_timesteps | 297178   |
# | train/             |          |
# |    actor_loss      | -3.73    |
# |    critic_loss     | 0.0568   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297077   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -8.87    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 6148     |
# |    fps             | 28       |
# |    time_elapsed    | 10274    |
# |    total_timesteps | 297280   |
# | train/             |          |
# |    actor_loss      | -3.12    |
# |    critic_loss     | 0.87     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -8.76    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 6152     |
# |    fps             | 28       |
# |    time_elapsed    | 10281    |
# |    total_timesteps | 297480   |
# | train/             |          |
# |    actor_loss      | -2.87    |
# |    critic_loss     | 0.489    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -8.7     |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 6156     |
# |    fps             | 28       |
# |    time_elapsed    | 10288    |
# |    total_timesteps | 297680   |
# | train/             |          |
# |    actor_loss      | -3.6     |
# |    critic_loss     | 0.224    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -8.66    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 6160     |
# |    fps             | 28       |
# |    time_elapsed    | 10295    |
# |    total_timesteps | 297880   |
# | train/             |          |
# |    actor_loss      | -2.47    |
# |    critic_loss     | 0.721    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -8.6     |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 6164     |
# |    fps             | 28       |
# |    time_elapsed    | 10302    |
# |    total_timesteps | 298080   |
# | train/             |          |
# |    actor_loss      | -3.15    |
# |    critic_loss     | 0.212    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297979   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -8.43    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 6168     |
# |    fps             | 28       |
# |    time_elapsed    | 10308    |
# |    total_timesteps | 298231   |
# | train/             |          |
# |    actor_loss      | -2.92    |
# |    critic_loss     | 0.164    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298130   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -8.33    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 6172     |
# |    fps             | 28       |
# |    time_elapsed    | 10315    |
# |    total_timesteps | 298431   |
# | train/             |          |
# |    actor_loss      | -3       |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298330   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -8.44    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 6176     |
# |    fps             | 28       |
# |    time_elapsed    | 10322    |
# |    total_timesteps | 298631   |
# | train/             |          |
# |    actor_loss      | -2.83    |
# |    critic_loss     | 0.333    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298530   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -8.39    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 6180     |
# |    fps             | 28       |
# |    time_elapsed    | 10329    |
# |    total_timesteps | 298831   |
# | train/             |          |
# |    actor_loss      | -3.46    |
# |    critic_loss     | 0.129    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298730   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -8.4     |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 6184     |
# |    fps             | 28       |
# |    time_elapsed    | 10336    |
# |    total_timesteps | 299031   |
# | train/             |          |
# |    actor_loss      | -3.33    |
# |    critic_loss     | 0.0498   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298930   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.2     |
# |    ep_rew_mean     | -8.52    |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 6188     |
# |    fps             | 28       |
# |    time_elapsed    | 10343    |
# |    total_timesteps | 299231   |
# | train/             |          |
# |    actor_loss      | -3.98    |
# |    critic_loss     | 0.0359   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299130   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | -8.66    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 6192     |
# |    fps             | 28       |
# |    time_elapsed    | 10351    |
# |    total_timesteps | 299431   |
# | train/             |          |
# |    actor_loss      | -3.11    |
# |    critic_loss     | 3.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299330   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.1     |
# |    ep_rew_mean     | -8.72    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 6196     |
# |    fps             | 28       |
# |    time_elapsed    | 10358    |
# |    total_timesteps | 299631   |
# | train/             |          |
# |    actor_loss      | -3.08    |
# |    critic_loss     | 0.0949   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299530   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.1     |
# |    ep_rew_mean     | -8.72    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 6200     |
# |    fps             | 28       |
# |    time_elapsed    | 10365    |
# |    total_timesteps | 299831   |
# | train/             |          |
# |    actor_loss      | -3.62    |
# |    critic_loss     | 0.0978   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299730   |
# ---------------------------------
# Eval num_timesteps=300000, episode_reward=-7.12 +/- 2.05
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -7.12    |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | -3.98    |
# |    critic_loss     | 0.0455   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299899   |
# ---------------------------------

# %%
model.save("ddpg_her_dense_no_flat_panda_pick_and_place")
print("Model saved.")
# Out:
# Model saved.

# %%
# Load a trained model
model = DDPG.load("ddpg_her_dense_no_flat_panda_pick_and_place", env=train_env)
print("Model loaded.")
# Out:
# Model loaded.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load evaluation results
eval_data = np.load("./ddpg_her_dense_no_flat_logs/evaluations.npz")
timesteps = eval_data["timesteps"]
results = eval_data["results"]  # shape = (n_evals, n_eval_episodes)

# Compute average and std over episodes
mean_rewards = results.mean(axis=1)
std_rewards = results.std(axis=1)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(timesteps, mean_rewards, label="Mean Reward")
plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3)
plt.xlabel("Episodes")
plt.ylabel("Average Reward")
plt.title("DDPG Her Dense Evaluation Rewards Over Time")
plt.grid(True)
plt.legend()
plt.show()

# %%
from gymnasium.wrappers import FlattenObservation
import time

# Create renderable environment with flattened observation space
env = gym.make("PandaPickAndPlace-v3", render_mode="human")
# env = FlattenObservation(env)

# Load model
model = DDPG.load("ddpg_her_dense_no_flat_panda_pick_and_place", env=env)

# Run a few episodes
episodes = 300

for ep in range(episodes):
    obs, _ = env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        env.render()
        total_reward += reward
        time.sleep(0.05)  # Slow down rendering

    print(f"Episode {ep+1} - Total Reward: {total_reward}")

env.close()
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# argc=5
# argv[0] = --unused
# argv[1] = --background_color_red=0.8745098114013672
# argv[2] = --background_color_green=0.21176470816135406
# argv[3] = --background_color_blue=0.1764705926179886
# argv[4] = --start_demo_name=Physics Server
# ExampleBrowserThreadFunc started
# X11 functions dynamically loaded using dlopen/dlsym OK!
# X11 functions dynamically loaded using dlopen/dlsym OK!
# Creating context
# Created GL 3.3 context
# Direct GLX rendering context obtained
# Making context current
# GL_VENDOR=NVIDIA Corporation
# GL_RENDERER=NVIDIA GeForce RTX 2070 Super with Max-Q Design/PCIe/SSE2
# GL_VERSION=3.3.0 NVIDIA 550.120
# GL_SHADING_LANGUAGE_VERSION=3.30 NVIDIA via Cg compiler
# pthread_getconcurrency()=0
# Version = 3.3.0 NVIDIA 550.120
# Vendor = NVIDIA Corporation
# Renderer = NVIDIA GeForce RTX 2070 Super with Max-Q Design/PCIe/SSE2
# b3Printf: Selected demo: Physics Server
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# MotionThreadFunc thread started
# ven = NVIDIA Corporation
# ven = NVIDIA Corporation
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode 1 - Total Reward: -50.0
# Episode 2 - Total Reward: -50.0
# Episode 3 - Total Reward: -50.0
# Episode 4 - Total Reward: -50.0
# Episode 5 - Total Reward: -50.0
# Episode 6 - Total Reward: -50.0
# Episode 7 - Total Reward: -50.0
# Episode 8 - Total Reward: -50.0
# Episode 9 - Total Reward: -50.0
# Episode 10 - Total Reward: -50.0
# Episode 11 - Total Reward: -50.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 25
#      23         env.render()
#      24         total_reward += reward
# ---> 25         time.sleep(0.05)  # Slow down rendering
#      27     print(f"Episode {ep+1} - Total Reward: {total_reward}")
#      29 env.close()
#
# KeyboardInterrupt:

# %%
env.close()
# Out:
# numActiveThreads = 0
# stopping threads
# Thread with taskId 0 exiting
# Thread TERMINATED
# destroy semaphore
# semaphore destroyed
# destroy main semaphore
# main semaphore destroyed
# finished
# numActiveThreads = 0
# btShutDownExampleBrowser stopping threads
# Thread with taskId 0 exiting
# Thread TERMINATED
# destroy semaphore
# semaphore destroyed
# destroy main semaphore
# main semaphore destroyed
