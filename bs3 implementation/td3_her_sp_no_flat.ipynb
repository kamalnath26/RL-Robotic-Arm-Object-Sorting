# %%
import gymnasium as gym
import panda_gym
from stable_baselines3 import TD3
from stable_baselines3.her import HerReplayBuffer
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from stable_baselines3.common.callbacks import EvalCallback

# %%
# Training environment
train_env = gym.make("PandaPickAndPlace-v3")
train_env = Monitor(train_env)
train_env = DummyVecEnv([lambda: train_env])
train_env = VecMonitor(train_env)

# Evaluation environment
eval_env = gym.make("PandaPickAndPlace-v3")
eval_env = Monitor(eval_env)
eval_env = DummyVecEnv([lambda: eval_env])
eval_env = VecMonitor(eval_env)
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# /home/kamal/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/vec_monitor.py:44: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(

# %%
model = TD3(
    policy="MultiInputPolicy",                 # Dict observation support
    env=train_env,
    replay_buffer_class=HerReplayBuffer,       # HER for sparse rewards
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future"
    ),
    verbose=1,
    tensorboard_log="./td3_her_sp_no_flat_tensorboard/"
)
# Out:
# Using cuda device

# %%
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./td3_her_sp_no_flat_best_model/",
    log_path="./td3_her_sp_no_flat_logs/",
    eval_freq=5000,
    deterministic=True,
    render=False
)

model.learn(total_timesteps=300_000, callback=eval_callback)
# Out:
# Logging to ./td3_her_sp_no_flat_tensorboard/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 56       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 0.216    |
# |    critic_loss     | 0.197    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 41       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | 0.235    |
# |    critic_loss     | 0.0764   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 38       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | 0.132    |
# |    critic_loss     | 0.033    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 36       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | 0.0936   |
# |    critic_loss     | 0.0159   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 36       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | 0.306    |
# |    critic_loss     | 0.0575   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -47.9    |
# |    success_rate    | 0.0417   |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 37       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 1151     |
# | train/             |          |
# |    actor_loss      | 0.421    |
# |    critic_loss     | 0.037    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1050     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.2     |
# |    ep_rew_mean     | -48.2    |
# |    success_rate    | 0.0357   |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 36       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 1351     |
# | train/             |          |
# |    actor_loss      | 0.415    |
# |    critic_loss     | 0.022    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1250     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.9     |
# |    ep_rew_mean     | -46.9    |
# |    success_rate    | 0.0625   |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 36       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 1502     |
# | train/             |          |
# |    actor_loss      | 0.451    |
# |    critic_loss     | 0.0314   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1401     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.3     |
# |    ep_rew_mean     | -47.2    |
# |    success_rate    | 0.0556   |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 36       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 1702     |
# | train/             |          |
# |    actor_loss      | 0.509    |
# |    critic_loss     | 0.0235   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1601     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 36       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 1902     |
# | train/             |          |
# |    actor_loss      | 0.562    |
# |    critic_loss     | 0.0191   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1801     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.8     |
# |    ep_rew_mean     | -47.7    |
# |    success_rate    | 0.0455   |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 35       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 2102     |
# | train/             |          |
# |    actor_loss      | 0.64     |
# |    critic_loss     | 0.0115   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2001     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -47.9    |
# |    success_rate    | 0.0417   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 35       |
# |    time_elapsed    | 64       |
# |    total_timesteps | 2302     |
# | train/             |          |
# |    actor_loss      | 0.522    |
# |    critic_loss     | 0.0168   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2201     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.0385   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 35       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 2502     |
# | train/             |          |
# |    actor_loss      | 0.614    |
# |    critic_loss     | 0.0182   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2401     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.2     |
# |    ep_rew_mean     | -48.2    |
# |    success_rate    | 0.0357   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 34       |
# |    time_elapsed    | 77       |
# |    total_timesteps | 2702     |
# | train/             |          |
# |    actor_loss      | 0.891    |
# |    critic_loss     | 0.0314   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2601     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.4     |
# |    ep_rew_mean     | -48.3    |
# |    success_rate    | 0.0333   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 34       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 2902     |
# | train/             |          |
# |    actor_loss      | 0.905    |
# |    critic_loss     | 2.75     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2801     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.4    |
# |    success_rate    | 0.0312   |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 34       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 3102     |
# | train/             |          |
# |    actor_loss      | 0.92     |
# |    critic_loss     | 0.0416   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3001     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.0294   |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 34       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 3302     |
# | train/             |          |
# |    actor_loss      | 0.79     |
# |    critic_loss     | 0.0409   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3201     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.0278   |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 34       |
# |    time_elapsed    | 101      |
# |    total_timesteps | 3502     |
# | train/             |          |
# |    actor_loss      | 1        |
# |    critic_loss     | 0.0189   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3401     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.7     |
# |    ep_rew_mean     | -48.7    |
# |    success_rate    | 0.0263   |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 34       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 3702     |
# | train/             |          |
# |    actor_loss      | 0.973    |
# |    critic_loss     | 0.0228   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3601     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.8     |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 34       |
# |    time_elapsed    | 112      |
# |    total_timesteps | 3902     |
# | train/             |          |
# |    actor_loss      | 0.989    |
# |    critic_loss     | 0.0322   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3801     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.8     |
# |    ep_rew_mean     | -48.8    |
# |    success_rate    | 0.0238   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 34       |
# |    time_elapsed    | 118      |
# |    total_timesteps | 4102     |
# | train/             |          |
# |    actor_loss      | 1.19     |
# |    critic_loss     | 0.0126   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4001     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.9     |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0227   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 34       |
# |    time_elapsed    | 124      |
# |    total_timesteps | 4302     |
# | train/             |          |
# |    actor_loss      | 1.13     |
# |    critic_loss     | 0.0231   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4201     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.9     |
# |    ep_rew_mean     | -48.9    |
# |    success_rate    | 0.0217   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 34       |
# |    time_elapsed    | 130      |
# |    total_timesteps | 4502     |
# | train/             |          |
# |    actor_loss      | 1.17     |
# |    critic_loss     | 0.0174   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4401     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.0208   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 34       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 4702     |
# | train/             |          |
# |    actor_loss      | 1.46     |
# |    critic_loss     | 3.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4601     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 34       |
# |    time_elapsed    | 143      |
# |    total_timesteps | 4902     |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 0.0374   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4801     |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=-50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.0287   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4899     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 33       |
# |    time_elapsed    | 151      |
# |    total_timesteps | 5102     |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.0195   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5001     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 33       |
# |    time_elapsed    | 157      |
# |    total_timesteps | 5302     |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.0233   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5201     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 33       |
# |    time_elapsed    | 163      |
# |    total_timesteps | 5502     |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.0189   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5401     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 33       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 5702     |
# | train/             |          |
# |    actor_loss      | 1.8      |
# |    critic_loss     | 0.0759   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5601     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 34       |
# |    time_elapsed    | 173      |
# |    total_timesteps | 5902     |
# | train/             |          |
# |    actor_loss      | 1.88     |
# |    critic_loss     | 0.0549   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5801     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 34       |
# |    time_elapsed    | 178      |
# |    total_timesteps | 6102     |
# | train/             |          |
# |    actor_loss      | 2.03     |
# |    critic_loss     | 0.0194   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6001     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 34       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 6253     |
# | train/             |          |
# |    actor_loss      | 1.96     |
# |    critic_loss     | 0.0897   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6152     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 34       |
# |    time_elapsed    | 186      |
# |    total_timesteps | 6453     |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.0156   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 34       |
# |    time_elapsed    | 191      |
# |    total_timesteps | 6653     |
# | train/             |          |
# |    actor_loss      | 2.17     |
# |    critic_loss     | 0.029    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6552     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 34       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 6853     |
# | train/             |          |
# |    actor_loss      | 2.27     |
# |    critic_loss     | 0.0284   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6752     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 34       |
# |    time_elapsed    | 200      |
# |    total_timesteps | 7004     |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.0216   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6903     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 35       |
# |    time_elapsed    | 205      |
# |    total_timesteps | 7204     |
# | train/             |          |
# |    actor_loss      | 2.25     |
# |    critic_loss     | 0.0497   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7103     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 35       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 7404     |
# | train/             |          |
# |    actor_loss      | 2.46     |
# |    critic_loss     | 0.107    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7303     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 34       |
# |    time_elapsed    | 217      |
# |    total_timesteps | 7604     |
# | train/             |          |
# |    actor_loss      | 2.24     |
# |    critic_loss     | 0.0439   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7503     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 34       |
# |    time_elapsed    | 223      |
# |    total_timesteps | 7804     |
# | train/             |          |
# |    actor_loss      | 2.35     |
# |    critic_loss     | 0.0268   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7703     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 34       |
# |    time_elapsed    | 228      |
# |    total_timesteps | 7955     |
# | train/             |          |
# |    actor_loss      | 2.68     |
# |    critic_loss     | 0.0231   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7854     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 34       |
# |    time_elapsed    | 234      |
# |    total_timesteps | 8155     |
# | train/             |          |
# |    actor_loss      | 2.52     |
# |    critic_loss     | 0.0429   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 34       |
# |    time_elapsed    | 240      |
# |    total_timesteps | 8355     |
# | train/             |          |
# |    actor_loss      | 2.89     |
# |    critic_loss     | 0.205    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8254     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 34       |
# |    time_elapsed    | 246      |
# |    total_timesteps | 8555     |
# | train/             |          |
# |    actor_loss      | 2.69     |
# |    critic_loss     | 0.0302   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8454     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 34       |
# |    time_elapsed    | 252      |
# |    total_timesteps | 8755     |
# | train/             |          |
# |    actor_loss      | 2.81     |
# |    critic_loss     | 0.0237   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8654     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 34       |
# |    time_elapsed    | 258      |
# |    total_timesteps | 8955     |
# | train/             |          |
# |    actor_loss      | 2.76     |
# |    critic_loss     | 0.0177   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8854     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 34       |
# |    time_elapsed    | 264      |
# |    total_timesteps | 9155     |
# | train/             |          |
# |    actor_loss      | 3.08     |
# |    critic_loss     | 0.026    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 34       |
# |    time_elapsed    | 269      |
# |    total_timesteps | 9355     |
# | train/             |          |
# |    actor_loss      | 2.93     |
# |    critic_loss     | 0.0602   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9254     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 34       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 9555     |
# | train/             |          |
# |    actor_loss      | 3.08     |
# |    critic_loss     | 0.0349   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9454     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 35       |
# |    time_elapsed    | 278      |
# |    total_timesteps | 9755     |
# | train/             |          |
# |    actor_loss      | 3.31     |
# |    critic_loss     | 0.027    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9654     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 35       |
# |    time_elapsed    | 282      |
# |    total_timesteps | 9906     |
# | train/             |          |
# |    actor_loss      | 3.15     |
# |    critic_loss     | 0.0289   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9805     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-40.00 +/- 20.00
# Episode length: 40.20 +/- 19.60
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 40.2     |
# |    mean_reward     | -40      |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 3.4      |
# |    critic_loss     | 0.0393   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9899     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 35       |
# |    time_elapsed    | 287      |
# |    total_timesteps | 10106    |
# | train/             |          |
# |    actor_loss      | 3.99     |
# |    critic_loss     | 0.0714   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10005    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 35       |
# |    time_elapsed    | 292      |
# |    total_timesteps | 10306    |
# | train/             |          |
# |    actor_loss      | 3.65     |
# |    critic_loss     | 0.0373   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10205    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 35       |
# |    time_elapsed    | 296      |
# |    total_timesteps | 10457    |
# | train/             |          |
# |    actor_loss      | 3.7      |
# |    critic_loss     | 0.0794   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10356    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 35       |
# |    time_elapsed    | 301      |
# |    total_timesteps | 10657    |
# | train/             |          |
# |    actor_loss      | 3.14     |
# |    critic_loss     | 0.168    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10556    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 35       |
# |    time_elapsed    | 306      |
# |    total_timesteps | 10857    |
# | train/             |          |
# |    actor_loss      | 3.77     |
# |    critic_loss     | 0.026    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10756    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 35       |
# |    time_elapsed    | 312      |
# |    total_timesteps | 11057    |
# | train/             |          |
# |    actor_loss      | 3.58     |
# |    critic_loss     | 0.0601   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10956    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 35       |
# |    time_elapsed    | 317      |
# |    total_timesteps | 11257    |
# | train/             |          |
# |    actor_loss      | 4        |
# |    critic_loss     | 0.105    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11156    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 35       |
# |    time_elapsed    | 322      |
# |    total_timesteps | 11457    |
# | train/             |          |
# |    actor_loss      | 4.12     |
# |    critic_loss     | 0.921    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11356    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 35       |
# |    time_elapsed    | 327      |
# |    total_timesteps | 11657    |
# | train/             |          |
# |    actor_loss      | 3.96     |
# |    critic_loss     | 0.113    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11556    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 35       |
# |    time_elapsed    | 332      |
# |    total_timesteps | 11857    |
# | train/             |          |
# |    actor_loss      | 4.32     |
# |    critic_loss     | 0.145    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11756    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 35       |
# |    time_elapsed    | 336      |
# |    total_timesteps | 12008    |
# | train/             |          |
# |    actor_loss      | 4.29     |
# |    critic_loss     | 0.0673   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 35       |
# |    time_elapsed    | 342      |
# |    total_timesteps | 12208    |
# | train/             |          |
# |    actor_loss      | 4.45     |
# |    critic_loss     | 0.109    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12107    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 35       |
# |    time_elapsed    | 347      |
# |    total_timesteps | 12408    |
# | train/             |          |
# |    actor_loss      | 3.87     |
# |    critic_loss     | 0.73     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12307    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 35       |
# |    time_elapsed    | 352      |
# |    total_timesteps | 12608    |
# | train/             |          |
# |    actor_loss      | 4.1      |
# |    critic_loss     | 0.163    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12507    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 35       |
# |    time_elapsed    | 358      |
# |    total_timesteps | 12808    |
# | train/             |          |
# |    actor_loss      | 3.84     |
# |    critic_loss     | 0.107    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12707    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 35       |
# |    time_elapsed    | 363      |
# |    total_timesteps | 13008    |
# | train/             |          |
# |    actor_loss      | 4.04     |
# |    critic_loss     | 0.0471   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 35       |
# |    time_elapsed    | 368      |
# |    total_timesteps | 13208    |
# | train/             |          |
# |    actor_loss      | 4.46     |
# |    critic_loss     | 4.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13107    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 35       |
# |    time_elapsed    | 373      |
# |    total_timesteps | 13408    |
# | train/             |          |
# |    actor_loss      | 4.44     |
# |    critic_loss     | 0.301    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13307    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 35       |
# |    time_elapsed    | 378      |
# |    total_timesteps | 13608    |
# | train/             |          |
# |    actor_loss      | 4.59     |
# |    critic_loss     | 0.212    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13507    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 35       |
# |    time_elapsed    | 384      |
# |    total_timesteps | 13808    |
# | train/             |          |
# |    actor_loss      | 4.45     |
# |    critic_loss     | 0.163    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13707    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 36       |
# |    time_elapsed    | 389      |
# |    total_timesteps | 14008    |
# | train/             |          |
# |    actor_loss      | 4.06     |
# |    critic_loss     | 0.219    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 36       |
# |    time_elapsed    | 394      |
# |    total_timesteps | 14208    |
# | train/             |          |
# |    actor_loss      | 4.76     |
# |    critic_loss     | 0.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14107    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 35       |
# |    time_elapsed    | 400      |
# |    total_timesteps | 14408    |
# | train/             |          |
# |    actor_loss      | 4.65     |
# |    critic_loss     | 0.248    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14307    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 35       |
# |    time_elapsed    | 406      |
# |    total_timesteps | 14608    |
# | train/             |          |
# |    actor_loss      | 4.93     |
# |    critic_loss     | 0.0973   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14507    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 35       |
# |    time_elapsed    | 412      |
# |    total_timesteps | 14808    |
# | train/             |          |
# |    actor_loss      | 4.75     |
# |    critic_loss     | 0.285    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14707    |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=-50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | 4.76     |
# |    critic_loss     | 0.279    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 35       |
# |    time_elapsed    | 419      |
# |    total_timesteps | 15008    |
# | train/             |          |
# |    actor_loss      | 5.02     |
# |    critic_loss     | 1.69     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 35       |
# |    time_elapsed    | 425      |
# |    total_timesteps | 15208    |
# | train/             |          |
# |    actor_loss      | 4.89     |
# |    critic_loss     | 0.242    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15107    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 35       |
# |    time_elapsed    | 430      |
# |    total_timesteps | 15408    |
# | train/             |          |
# |    actor_loss      | 4.62     |
# |    critic_loss     | 1.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15307    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 35       |
# |    time_elapsed    | 435      |
# |    total_timesteps | 15608    |
# | train/             |          |
# |    actor_loss      | 4.78     |
# |    critic_loss     | 0.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15507    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 35       |
# |    time_elapsed    | 439      |
# |    total_timesteps | 15808    |
# | train/             |          |
# |    actor_loss      | 4.74     |
# |    critic_loss     | 0.361    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15707    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 36       |
# |    time_elapsed    | 444      |
# |    total_timesteps | 16008    |
# | train/             |          |
# |    actor_loss      | 4.96     |
# |    critic_loss     | 0.154    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 36       |
# |    time_elapsed    | 447      |
# |    total_timesteps | 16159    |
# | train/             |          |
# |    actor_loss      | 4.92     |
# |    critic_loss     | 0.381    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16058    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 36       |
# |    time_elapsed    | 452      |
# |    total_timesteps | 16359    |
# | train/             |          |
# |    actor_loss      | 5.01     |
# |    critic_loss     | 0.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16258    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 36       |
# |    time_elapsed    | 456      |
# |    total_timesteps | 16559    |
# | train/             |          |
# |    actor_loss      | 5.06     |
# |    critic_loss     | 0.171    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16458    |
# ---------------------------------
# ...
# | train/             |          |
# |    actor_loss      | 35.1     |
# |    critic_loss     | 13.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294506   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6132     |
# |    fps             | 26       |
# |    time_elapsed    | 10975    |
# |    total_timesteps | 294807   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 27.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294706   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 6136     |
# |    fps             | 26       |
# |    time_elapsed    | 10978    |
# |    total_timesteps | 294958   |
# | train/             |          |
# |    actor_loss      | 39.7     |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294857   |
# ---------------------------------
# Eval num_timesteps=295000, episode_reward=-50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 295000   |
# | train/             |          |
# |    actor_loss      | 37.8     |
# |    critic_loss     | 20.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 6140     |
# |    fps             | 26       |
# |    time_elapsed    | 10984    |
# |    total_timesteps | 295158   |
# | train/             |          |
# |    actor_loss      | 37.3     |
# |    critic_loss     | 19.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295057   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 6144     |
# |    fps             | 26       |
# |    time_elapsed    | 10988    |
# |    total_timesteps | 295358   |
# | train/             |          |
# |    actor_loss      | 35.2     |
# |    critic_loss     | 16.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295257   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -47.1    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 6148     |
# |    fps             | 26       |
# |    time_elapsed    | 10992    |
# |    total_timesteps | 295509   |
# | train/             |          |
# |    actor_loss      | 35       |
# |    critic_loss     | 46.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -47.1    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 6152     |
# |    fps             | 26       |
# |    time_elapsed    | 10996    |
# |    total_timesteps | 295709   |
# | train/             |          |
# |    actor_loss      | 36.1     |
# |    critic_loss     | 33.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 6156     |
# |    fps             | 26       |
# |    time_elapsed    | 11001    |
# |    total_timesteps | 295909   |
# | train/             |          |
# |    actor_loss      | 36.5     |
# |    critic_loss     | 50.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 6160     |
# |    fps             | 26       |
# |    time_elapsed    | 11006    |
# |    total_timesteps | 296109   |
# | train/             |          |
# |    actor_loss      | 34.3     |
# |    critic_loss     | 7.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296008   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6164     |
# |    fps             | 26       |
# |    time_elapsed    | 11010    |
# |    total_timesteps | 296309   |
# | train/             |          |
# |    actor_loss      | 39.1     |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296208   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6168     |
# |    fps             | 26       |
# |    time_elapsed    | 11015    |
# |    total_timesteps | 296509   |
# | train/             |          |
# |    actor_loss      | 38.2     |
# |    critic_loss     | 17.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6172     |
# |    fps             | 26       |
# |    time_elapsed    | 11020    |
# |    total_timesteps | 296709   |
# | train/             |          |
# |    actor_loss      | 35.7     |
# |    critic_loss     | 454      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6176     |
# |    fps             | 26       |
# |    time_elapsed    | 11024    |
# |    total_timesteps | 296909   |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 13.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6180     |
# |    fps             | 26       |
# |    time_elapsed    | 11029    |
# |    total_timesteps | 297109   |
# | train/             |          |
# |    actor_loss      | 36.9     |
# |    critic_loss     | 12.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297008   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6184     |
# |    fps             | 26       |
# |    time_elapsed    | 11034    |
# |    total_timesteps | 297309   |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 15.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297208   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6188     |
# |    fps             | 26       |
# |    time_elapsed    | 11038    |
# |    total_timesteps | 297509   |
# | train/             |          |
# |    actor_loss      | 34.2     |
# |    critic_loss     | 11.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297408   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6192     |
# |    fps             | 26       |
# |    time_elapsed    | 11043    |
# |    total_timesteps | 297709   |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 9.07     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 6196     |
# |    fps             | 26       |
# |    time_elapsed    | 11047    |
# |    total_timesteps | 297909   |
# | train/             |          |
# |    actor_loss      | 34       |
# |    critic_loss     | 8.08     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6200     |
# |    fps             | 26       |
# |    time_elapsed    | 11051    |
# |    total_timesteps | 298071   |
# | train/             |          |
# |    actor_loss      | 36       |
# |    critic_loss     | 24.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297970   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6204     |
# |    fps             | 26       |
# |    time_elapsed    | 11056    |
# |    total_timesteps | 298271   |
# | train/             |          |
# |    actor_loss      | 34.5     |
# |    critic_loss     | 6.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298170   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6208     |
# |    fps             | 26       |
# |    time_elapsed    | 11061    |
# |    total_timesteps | 298471   |
# | train/             |          |
# |    actor_loss      | 35.9     |
# |    critic_loss     | 6.93     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298370   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6212     |
# |    fps             | 26       |
# |    time_elapsed    | 11065    |
# |    total_timesteps | 298671   |
# | train/             |          |
# |    actor_loss      | 37.3     |
# |    critic_loss     | 37.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298570   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6216     |
# |    fps             | 26       |
# |    time_elapsed    | 11070    |
# |    total_timesteps | 298871   |
# | train/             |          |
# |    actor_loss      | 35.2     |
# |    critic_loss     | 10.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298770   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6220     |
# |    fps             | 27       |
# |    time_elapsed    | 11075    |
# |    total_timesteps | 299071   |
# | train/             |          |
# |    actor_loss      | 38.6     |
# |    critic_loss     | 12.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298970   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 6224     |
# |    fps             | 27       |
# |    time_elapsed    | 11079    |
# |    total_timesteps | 299271   |
# | train/             |          |
# |    actor_loss      | 35.2     |
# |    critic_loss     | 110      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299170   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 6228     |
# |    fps             | 27       |
# |    time_elapsed    | 11084    |
# |    total_timesteps | 299471   |
# | train/             |          |
# |    actor_loss      | 35.4     |
# |    critic_loss     | 11       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299370   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 6232     |
# |    fps             | 27       |
# |    time_elapsed    | 11089    |
# |    total_timesteps | 299671   |
# | train/             |          |
# |    actor_loss      | 34.7     |
# |    critic_loss     | 9.55     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299570   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | -49.1    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 6236     |
# |    fps             | 27       |
# |    time_elapsed    | 11094    |
# |    total_timesteps | 299871   |
# | train/             |          |
# |    actor_loss      | 34.4     |
# |    critic_loss     | 31.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299770   |
# ---------------------------------
# Eval num_timesteps=300000, episode_reward=-40.00 +/- 20.00
# Episode length: 40.20 +/- 19.60
# Success rate: 20.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 40.2     |
# |    mean_reward     | -40      |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | 37.8     |
# |    critic_loss     | 30.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299899   |
# ---------------------------------

# %%
model.save("td3_her_sp_no_flat_panda_pick_and_place")
print("Model saved.")
# Out:
# Model saved.

# %%
# Load a trained model
model = TD3.load("td3_her_sp_no_flat_panda_pick_and_place", env=train_env)
print("Model loaded.")
# Out:
# Model loaded.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load evaluation results
eval_data = np.load("./td3_her_sp_no_flat_logs/evaluations.npz")
timesteps = eval_data["timesteps"]
results = eval_data["results"]  # shape = (n_evals, n_eval_episodes)

# Compute average and std over episodes
mean_rewards = results.mean(axis=1)
std_rewards = results.std(axis=1)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(timesteps, mean_rewards, label="Mean Reward")
plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3)
plt.xlabel("Episodes")
plt.ylabel("Average Reward")
plt.title("TD3 HER Sparse Evaluation Rewards Over Time")
plt.grid(True)
plt.legend()
plt.show()

# %%
from gymnasium.wrappers import FlattenObservation
import time

# Create renderable environment with flattened observation space
env = gym.make("PandaPickAndPlace-v3", render_mode="human")
# env = FlattenObservation(env)

# Load model
model = TD3.load("td3_her_sp_no_flat_panda_pick_and_place", env=env)

# Run a few episodes
episodes = 300

for ep in range(episodes):
    obs, _ = env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        env.render()
        total_reward += reward
        time.sleep(0.05)  # Slow down rendering

    print(f"Episode {ep+1} - Total Reward: {total_reward}")

env.close()
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# argc=5
# argv[0] = --unused
# argv[1] = --background_color_red=0.8745098114013672
# argv[2] = --background_color_green=0.21176470816135406
# argv[3] = --background_color_blue=0.1764705926179886
# argv[4] = --start_demo_name=Physics Server
# ExampleBrowserThreadFunc started
# X11 functions dynamically loaded using dlopen/dlsym OK!
# X11 functions dynamically loaded using dlopen/dlsym OK!
# Creating context
# Created GL 3.3 context
# Direct GLX rendering context obtained
# Making context current
# GL_VENDOR=NVIDIA Corporation
# GL_RENDERER=NVIDIA GeForce RTX 2070 Super with Max-Q Design/PCIe/SSE2
# GL_VERSION=3.3.0 NVIDIA 550.120
# GL_SHADING_LANGUAGE_VERSION=3.30 NVIDIA via Cg compiler
# pthread_getconcurrency()=0
# Version = 3.3.0 NVIDIA 550.120
# Vendor = NVIDIA Corporation
# Renderer = NVIDIA GeForce RTX 2070 Super with Max-Q Design/PCIe/SSE2
# b3Printf: Selected demo: Physics Server
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# MotionThreadFunc thread started
# ven = NVIDIA Corporation
# ven = NVIDIA Corporation
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode 1 - Total Reward: -50.0
# Episode 2 - Total Reward: -50.0
# Episode 3 - Total Reward: -50.0
# Episode 4 - Total Reward: -50.0
# Episode 5 - Total Reward: -50.0
# Episode 6 - Total Reward: -50.0
# Episode 7 - Total Reward: -50.0
# Episode 8 - Total Reward: -50.0
# Episode 9 - Total Reward: -50.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 25
#      23         env.render()
#      24         total_reward += reward
# ---> 25         time.sleep(0.05)  # Slow down rendering
#      27     print(f"Episode {ep+1} - Total Reward: {total_reward}")
#      29 env.close()
#
# KeyboardInterrupt:

# %%
env.close()
# Out:
# numActiveThreads = 0
# stopping threads
# Thread with taskId 0 exiting
# Thread TERMINATED
# destroy semaphore
# semaphore destroyed
# destroy main semaphore
# main semaphore destroyed
# finished
# numActiveThreads = 0
# btShutDownExampleBrowser stopping threads
# Thread with taskId 0 exiting
# Thread TERMINATED
# destroy semaphore
# semaphore destroyed
# destroy main semaphore
# main semaphore destroyed
