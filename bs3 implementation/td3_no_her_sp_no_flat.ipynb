# %%
import gymnasium as gym
import panda_gym
from stable_baselines3 import TD3
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from stable_baselines3.common.callbacks import EvalCallback

# %%
# Training environment (sparse reward)
train_env = gym.make("PandaPickAndPlace-v3")
train_env = Monitor(train_env)
train_env = DummyVecEnv([lambda: train_env])
train_env = VecMonitor(train_env)

# Evaluation environment
eval_env = gym.make("PandaPickAndPlace-v3")
eval_env = Monitor(eval_env)
eval_env = DummyVecEnv([lambda: eval_env])
eval_env = VecMonitor(eval_env)
# Out:
# pybullet build time: Jan 29 2025 23:16:28
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# /home/kamal/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/vec_monitor.py:44: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(

# %%
model = TD3(
    policy="MultiInputPolicy",               # Dict observation support
    env=train_env,
    verbose=1,
    tensorboard_log="./td3_no_her_sp_no_flat_tensorboard/"
)
# Out:
# Using cuda device

# %%
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./td3_no_her_sp_no_flat_best_model/",
    log_path="./td3_no_her_sp_no_flat_logs/",
    eval_freq=5000,
    deterministic=True,
    render=False
)

model.learn(total_timesteps=300_000, callback=eval_callback)
# Out:
# Logging to ./td3_no_her_sp_no_flat_tensorboard/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 49       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 1.2      |
# |    critic_loss     | 0.00174  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 38       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.000434 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 36       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | 1.96     |
# |    critic_loss     | 0.000247 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 35       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | 2.35     |
# |    critic_loss     | 0.000298 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 34       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | 2.76     |
# |    critic_loss     | 0.000392 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 33       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | 3.16     |
# |    critic_loss     | 0.0004   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 32       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | 3.59     |
# |    critic_loss     | 0.000375 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 33       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | 4.03     |
# |    critic_loss     | 0.00699  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 33       |
# |    time_elapsed    | 54       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | 4.41     |
# |    critic_loss     | 0.00534  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 32       |
# |    time_elapsed    | 61       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | 4.75     |
# |    critic_loss     | 0.00733  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 32       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | 5.22     |
# |    critic_loss     | 0.0303   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 32       |
# |    time_elapsed    | 74       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | 5.46     |
# |    critic_loss     | 0.0072   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 32       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | 5.88     |
# |    critic_loss     | 0.00933  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 32       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | 6.35     |
# |    critic_loss     | 0.00937  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 32       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | 6.81     |
# |    critic_loss     | 0.00809  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 31       |
# |    time_elapsed    | 100      |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | 7.36     |
# |    critic_loss     | 0.0223   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 31       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 3400     |
# | train/             |          |
# |    actor_loss      | 7.83     |
# |    critic_loss     | 0.00578  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 31       |
# |    time_elapsed    | 113      |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | 8.19     |
# |    critic_loss     | 0.0156   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 31       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 3800     |
# | train/             |          |
# |    actor_loss      | 8.68     |
# |    critic_loss     | 0.0079   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 31       |
# |    time_elapsed    | 126      |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 9.09     |
# |    critic_loss     | 0.159    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 31       |
# |    time_elapsed    | 132      |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | 9.64     |
# |    critic_loss     | 0.0601   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 31       |
# |    time_elapsed    | 139      |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | 10       |
# |    critic_loss     | 0.0147   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 31       |
# |    time_elapsed    | 145      |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | 10.4     |
# |    critic_loss     | 0.0191   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.0104   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 31       |
# |    time_elapsed    | 150      |
# |    total_timesteps | 4751     |
# | train/             |          |
# |    actor_loss      | 10.8     |
# |    critic_loss     | 0.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4650     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 31       |
# |    time_elapsed    | 156      |
# |    total_timesteps | 4951     |
# | train/             |          |
# |    actor_loss      | 11.2     |
# |    critic_loss     | 0.847    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4850     |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=-50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | 11       |
# |    critic_loss     | 0.0264   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4899     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 31       |
# |    time_elapsed    | 164      |
# |    total_timesteps | 5151     |
# | train/             |          |
# |    actor_loss      | 11.3     |
# |    critic_loss     | 0.0357   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5050     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 31       |
# |    time_elapsed    | 169      |
# |    total_timesteps | 5302     |
# | train/             |          |
# |    actor_loss      | 11.7     |
# |    critic_loss     | 0.0977   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5201     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 31       |
# |    time_elapsed    | 174      |
# |    total_timesteps | 5453     |
# | train/             |          |
# |    actor_loss      | 11.9     |
# |    critic_loss     | 0.0239   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 31       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 5653     |
# | train/             |          |
# |    actor_loss      | 12.3     |
# |    critic_loss     | 0.0353   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5552     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 31       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 5853     |
# | train/             |          |
# |    actor_loss      | 12.4     |
# |    critic_loss     | 0.198    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5752     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 31       |
# |    time_elapsed    | 191      |
# |    total_timesteps | 6053     |
# | train/             |          |
# |    actor_loss      | 13       |
# |    critic_loss     | 0.058    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5952     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 31       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 6253     |
# | train/             |          |
# |    actor_loss      | 13.3     |
# |    critic_loss     | 0.0904   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6152     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 31       |
# |    time_elapsed    | 202      |
# |    total_timesteps | 6453     |
# | train/             |          |
# |    actor_loss      | 13.9     |
# |    critic_loss     | 0.281    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 31       |
# |    time_elapsed    | 209      |
# |    total_timesteps | 6653     |
# | train/             |          |
# |    actor_loss      | 14.2     |
# |    critic_loss     | 0.0783   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6552     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 31       |
# |    time_elapsed    | 215      |
# |    total_timesteps | 6853     |
# | train/             |          |
# |    actor_loss      | 14.4     |
# |    critic_loss     | 0.114    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6752     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 31       |
# |    time_elapsed    | 220      |
# |    total_timesteps | 7004     |
# | train/             |          |
# |    actor_loss      | 14.7     |
# |    critic_loss     | 0.0995   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6903     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 31       |
# |    time_elapsed    | 225      |
# |    total_timesteps | 7155     |
# | train/             |          |
# |    actor_loss      | 14.9     |
# |    critic_loss     | 0.176    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 31       |
# |    time_elapsed    | 232      |
# |    total_timesteps | 7355     |
# | train/             |          |
# |    actor_loss      | 15.1     |
# |    critic_loss     | 0.096    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7254     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 31       |
# |    time_elapsed    | 238      |
# |    total_timesteps | 7555     |
# | train/             |          |
# |    actor_loss      | 15.5     |
# |    critic_loss     | 0.317    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7454     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 31       |
# |    time_elapsed    | 245      |
# |    total_timesteps | 7755     |
# | train/             |          |
# |    actor_loss      | 16       |
# |    critic_loss     | 0.206    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7654     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 31       |
# |    time_elapsed    | 252      |
# |    total_timesteps | 7955     |
# | train/             |          |
# |    actor_loss      | 16.3     |
# |    critic_loss     | 0.302    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7854     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 31       |
# |    time_elapsed    | 258      |
# |    total_timesteps | 8155     |
# | train/             |          |
# |    actor_loss      | 16.4     |
# |    critic_loss     | 0.143    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 31       |
# |    time_elapsed    | 264      |
# |    total_timesteps | 8355     |
# | train/             |          |
# |    actor_loss      | 16.7     |
# |    critic_loss     | 0.226    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8254     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 31       |
# |    time_elapsed    | 270      |
# |    total_timesteps | 8555     |
# | train/             |          |
# |    actor_loss      | 17       |
# |    critic_loss     | 0.193    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8454     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 31       |
# |    time_elapsed    | 275      |
# |    total_timesteps | 8755     |
# | train/             |          |
# |    actor_loss      | 17.7     |
# |    critic_loss     | 0.117    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8654     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 31       |
# |    time_elapsed    | 280      |
# |    total_timesteps | 8906     |
# | train/             |          |
# |    actor_loss      | 17.7     |
# |    critic_loss     | 0.162    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8805     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 31       |
# |    time_elapsed    | 286      |
# |    total_timesteps | 9106     |
# | train/             |          |
# |    actor_loss      | 18.2     |
# |    critic_loss     | 0.151    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9005     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.1     |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 31       |
# |    time_elapsed    | 291      |
# |    total_timesteps | 9306     |
# | train/             |          |
# |    actor_loss      | 18.4     |
# |    critic_loss     | 1.86     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9205     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 31       |
# |    time_elapsed    | 297      |
# |    total_timesteps | 9506     |
# | train/             |          |
# |    actor_loss      | 18.5     |
# |    critic_loss     | 0.117    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9405     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 32       |
# |    time_elapsed    | 302      |
# |    total_timesteps | 9706     |
# | train/             |          |
# |    actor_loss      | 19.2     |
# |    critic_loss     | 2.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9605     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 32       |
# |    time_elapsed    | 308      |
# |    total_timesteps | 9906     |
# | train/             |          |
# |    actor_loss      | 19.5     |
# |    critic_loss     | 0.183    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9805     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 19.3     |
# |    critic_loss     | 1.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 32       |
# |    time_elapsed    | 315      |
# |    total_timesteps | 10106    |
# | train/             |          |
# |    actor_loss      | 19.6     |
# |    critic_loss     | 0.151    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10005    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 32       |
# |    time_elapsed    | 320      |
# |    total_timesteps | 10306    |
# | train/             |          |
# |    actor_loss      | 19.8     |
# |    critic_loss     | 2.55     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10205    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 32       |
# |    time_elapsed    | 326      |
# |    total_timesteps | 10506    |
# | train/             |          |
# |    actor_loss      | 20.1     |
# |    critic_loss     | 2.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10405    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 32       |
# |    time_elapsed    | 331      |
# |    total_timesteps | 10706    |
# | train/             |          |
# |    actor_loss      | 20.5     |
# |    critic_loss     | 0.276    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10605    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 32       |
# |    time_elapsed    | 335      |
# |    total_timesteps | 10867    |
# | train/             |          |
# |    actor_loss      | 20.7     |
# |    critic_loss     | 0.265    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10766    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 32       |
# |    time_elapsed    | 341      |
# |    total_timesteps | 11067    |
# | train/             |          |
# |    actor_loss      | 21.2     |
# |    critic_loss     | 0.371    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10966    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 32       |
# |    time_elapsed    | 344      |
# |    total_timesteps | 11218    |
# | train/             |          |
# |    actor_loss      | 21.9     |
# |    critic_loss     | 0.346    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11117    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 32       |
# |    time_elapsed    | 349      |
# |    total_timesteps | 11418    |
# | train/             |          |
# |    actor_loss      | 21.5     |
# |    critic_loss     | 0.248    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11317    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 32       |
# |    time_elapsed    | 355      |
# |    total_timesteps | 11618    |
# | train/             |          |
# |    actor_loss      | 22.2     |
# |    critic_loss     | 0.331    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11517    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 32       |
# |    time_elapsed    | 359      |
# |    total_timesteps | 11769    |
# | train/             |          |
# |    actor_loss      | 22.1     |
# |    critic_loss     | 0.221    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11668    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 32       |
# |    time_elapsed    | 364      |
# |    total_timesteps | 11969    |
# | train/             |          |
# |    actor_loss      | 22.6     |
# |    critic_loss     | 2.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11868    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 32       |
# |    time_elapsed    | 370      |
# |    total_timesteps | 12169    |
# | train/             |          |
# |    actor_loss      | 23       |
# |    critic_loss     | 2.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12068    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 32       |
# |    time_elapsed    | 375      |
# |    total_timesteps | 12369    |
# | train/             |          |
# |    actor_loss      | 22.9     |
# |    critic_loss     | 0.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12268    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 33       |
# |    time_elapsed    | 380      |
# |    total_timesteps | 12569    |
# | train/             |          |
# |    actor_loss      | 23.3     |
# |    critic_loss     | 0.491    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12468    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 33       |
# |    time_elapsed    | 385      |
# |    total_timesteps | 12769    |
# | train/             |          |
# |    actor_loss      | 23.8     |
# |    critic_loss     | 0.527    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12668    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 33       |
# |    time_elapsed    | 390      |
# |    total_timesteps | 12969    |
# | train/             |          |
# |    actor_loss      | 23.5     |
# |    critic_loss     | 0.609    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12868    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 33       |
# |    time_elapsed    | 395      |
# |    total_timesteps | 13169    |
# | train/             |          |
# |    actor_loss      | 24       |
# |    critic_loss     | 0.495    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13068    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 33       |
# |    time_elapsed    | 401      |
# |    total_timesteps | 13369    |
# | train/             |          |
# |    actor_loss      | 23.9     |
# |    critic_loss     | 3.79     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13268    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 33       |
# |    time_elapsed    | 406      |
# |    total_timesteps | 13569    |
# | train/             |          |
# |    actor_loss      | 24.5     |
# |    critic_loss     | 2.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13468    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 33       |
# |    time_elapsed    | 411      |
# |    total_timesteps | 13769    |
# | train/             |          |
# |    actor_loss      | 24.7     |
# |    critic_loss     | 0.472    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13668    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 33       |
# |    time_elapsed    | 416      |
# |    total_timesteps | 13969    |
# | train/             |          |
# |    actor_loss      | 25.6     |
# |    critic_loss     | 0.527    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13868    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 33       |
# |    time_elapsed    | 422      |
# |    total_timesteps | 14169    |
# | train/             |          |
# |    actor_loss      | 25.4     |
# |    critic_loss     | 3.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14068    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 33       |
# |    time_elapsed    | 427      |
# |    total_timesteps | 14369    |
# | train/             |          |
# |    actor_loss      | 25.9     |
# |    critic_loss     | 0.373    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14268    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 33       |
# |    time_elapsed    | 432      |
# |    total_timesteps | 14569    |
# | train/             |          |
# |    actor_loss      | 26.3     |
# |    critic_loss     | 0.463    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14468    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 33       |
# |    time_elapsed    | 438      |
# |    total_timesteps | 14769    |
# | train/             |          |
# |    actor_loss      | 26.6     |
# |    critic_loss     | 0.469    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14668    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 33       |
# |    time_elapsed    | 443      |
# |    total_timesteps | 14969    |
# | train/             |          |
# |    actor_loss      | 27.3     |
# |    critic_loss     | 0.482    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14868    |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=-50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | 27.3     |
# |    critic_loss     | 0.562    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 33       |
# |    time_elapsed    | 451      |
# |    total_timesteps | 15169    |
# | train/             |          |
# |    actor_loss      | 27.4     |
# |    critic_loss     | 0.649    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15068    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 33       |
# |    time_elapsed    | 456      |
# |    total_timesteps | 15369    |
# | train/             |          |
# |    actor_loss      | 27.6     |
# |    critic_loss     | 0.458    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15268    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | -48.6    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 33       |
# |    time_elapsed    | 462      |
# |    total_timesteps | 15569    |
# | train/             |          |
# |    actor_loss      | 27.7     |
# |    critic_loss     | 0.717    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15468    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 33       |
# |    time_elapsed    | 467      |
# |    total_timesteps | 15769    |
# | train/             |          |
# |    actor_loss      | 28.2     |
# |    critic_loss     | 0.566    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15668    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 33       |
# |    time_elapsed    | 472      |
# |    total_timesteps | 15969    |
# | train/             |          |
# |    actor_loss      | 28.4     |
# |    critic_loss     | 0.645    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15868    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 33       |
# |    time_elapsed    | 478      |
# |    total_timesteps | 16169    |
# | train/             |          |
# |    actor_loss      | 28.6     |
# |    critic_loss     | 0.883    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16068    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 33       |
# |    time_elapsed    | 483      |
# |    total_timesteps | 16369    |
# | train/             |          |
# |    actor_loss      | 29.2     |
# |    critic_loss     | 0.639    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16268    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 33       |
# |    time_elapsed    | 489      |
# |    total_timesteps | 16569    |
# | train/             |          |
# |    actor_loss      | 29.8     |
# |    critic_loss     | 0.568    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16468    |
# ---------------------------------
# ---------------------------------
# ...
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 18.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294398   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6124     |
# |    fps             | 33       |
# |    time_elapsed    | 8728     |
# |    total_timesteps | 294699   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 14.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294598   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6128     |
# |    fps             | 33       |
# |    time_elapsed    | 8732     |
# |    total_timesteps | 294899   |
# | train/             |          |
# |    actor_loss      | 111      |
# |    critic_loss     | 56.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294798   |
# ---------------------------------
# Eval num_timesteps=295000, episode_reward=-50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 295000   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 3.33     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6132     |
# |    fps             | 33       |
# |    time_elapsed    | 8738     |
# |    total_timesteps | 295099   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 4.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 294998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6136     |
# |    fps             | 33       |
# |    time_elapsed    | 8742     |
# |    total_timesteps | 295299   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 11.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295198   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6140     |
# |    fps             | 33       |
# |    time_elapsed    | 8747     |
# |    total_timesteps | 295499   |
# | train/             |          |
# |    actor_loss      | 111      |
# |    critic_loss     | 26.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295398   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6144     |
# |    fps             | 33       |
# |    time_elapsed    | 8751     |
# |    total_timesteps | 295699   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 5.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295598   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6148     |
# |    fps             | 33       |
# |    time_elapsed    | 8755     |
# |    total_timesteps | 295899   |
# | train/             |          |
# |    actor_loss      | 108      |
# |    critic_loss     | 4.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295798   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6152     |
# |    fps             | 33       |
# |    time_elapsed    | 8759     |
# |    total_timesteps | 296099   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 8.74     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295998   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6156     |
# |    fps             | 33       |
# |    time_elapsed    | 8763     |
# |    total_timesteps | 296299   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 6.92     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296198   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6160     |
# |    fps             | 33       |
# |    time_elapsed    | 8768     |
# |    total_timesteps | 296499   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 10.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296398   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6164     |
# |    fps             | 33       |
# |    time_elapsed    | 8772     |
# |    total_timesteps | 296699   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 3.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296598   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 6168     |
# |    fps             | 33       |
# |    time_elapsed    | 8777     |
# |    total_timesteps | 296899   |
# | train/             |          |
# |    actor_loss      | 108      |
# |    critic_loss     | 8.7      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296798   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6172     |
# |    fps             | 33       |
# |    time_elapsed    | 8780     |
# |    total_timesteps | 297050   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 6.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296949   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6176     |
# |    fps             | 33       |
# |    time_elapsed    | 8784     |
# |    total_timesteps | 297250   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 3.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297149   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6180     |
# |    fps             | 33       |
# |    time_elapsed    | 8788     |
# |    total_timesteps | 297450   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 5.54     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297349   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6184     |
# |    fps             | 33       |
# |    time_elapsed    | 8792     |
# |    total_timesteps | 297650   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 10.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297549   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6188     |
# |    fps             | 33       |
# |    time_elapsed    | 8796     |
# |    total_timesteps | 297850   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 24.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297749   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6192     |
# |    fps             | 33       |
# |    time_elapsed    | 8800     |
# |    total_timesteps | 298050   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 4.55     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297949   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6196     |
# |    fps             | 33       |
# |    time_elapsed    | 8805     |
# |    total_timesteps | 298250   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 4.95     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298149   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6200     |
# |    fps             | 33       |
# |    time_elapsed    | 8809     |
# |    total_timesteps | 298450   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 7.75     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298349   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6204     |
# |    fps             | 33       |
# |    time_elapsed    | 8813     |
# |    total_timesteps | 298650   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 5.07     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298549   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6208     |
# |    fps             | 33       |
# |    time_elapsed    | 8817     |
# |    total_timesteps | 298850   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 12       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298749   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6212     |
# |    fps             | 33       |
# |    time_elapsed    | 8822     |
# |    total_timesteps | 299050   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 21.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 298949   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6216     |
# |    fps             | 33       |
# |    time_elapsed    | 8826     |
# |    total_timesteps | 299250   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 6.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299149   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -49.5    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 6220     |
# |    fps             | 33       |
# |    time_elapsed    | 8830     |
# |    total_timesteps | 299450   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 8.87     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299349   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 6224     |
# |    fps             | 33       |
# |    time_elapsed    | 8833     |
# |    total_timesteps | 299601   |
# | train/             |          |
# |    actor_loss      | 109      |
# |    critic_loss     | 71.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299500   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 6228     |
# |    fps             | 33       |
# |    time_elapsed    | 8837     |
# |    total_timesteps | 299801   |
# | train/             |          |
# |    actor_loss      | 110      |
# |    critic_loss     | 88       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299700   |
# ---------------------------------
# Eval num_timesteps=300000, episode_reward=-50.00 +/- 0.00
# Episode length: 50.00 +/- 0.00
# Success rate: 0.00%
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 50       |
# |    mean_reward     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | 111      |
# |    critic_loss     | 6.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299899   |
# ---------------------------------

# %%
model.save("td3_no_her_sp_no_flat_panda_pick_and_place")
print("Model saved.")
# Out:
# Model saved.

# %%
# Load a trained model
model = TD3.load("td3_no_her_sp_no_flat_panda_pick_and_place", env=train_env)
print("Model loaded.")
# Out:
# Model loaded.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load evaluation results
eval_data = np.load("./td3_no_her_sp_no_flat_logs/evaluations.npz")
timesteps = eval_data["timesteps"]
results = eval_data["results"]  # shape = (n_evals, n_eval_episodes)

# Compute average and std over episodes
mean_rewards = results.mean(axis=1)
std_rewards = results.std(axis=1)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(timesteps, mean_rewards, label="Mean Reward")
plt.fill_between(timesteps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.3)
plt.xlabel("Episodes")
plt.ylabel("Average Reward")
plt.title("TD3 Sparse Evaluation Rewards Over Time")
plt.grid(True)
plt.legend()
plt.show()

# %%
from gymnasium.wrappers import FlattenObservation
import time

# Create renderable environment with flattened observation space
env = gym.make("PandaPickAndPlace-v3", render_mode="human")
# env = FlattenObservation(env)

# Load model
model = TD3.load("td3_no_her_sp_no_flat_panda_pick_and_place", env=env)

# Run a few episodes
episodes = 300

for ep in range(episodes):
    obs, _ = env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        env.render()
        total_reward += reward
        time.sleep(0.05)  # Slow down rendering

    print(f"Episode {ep+1} - Total Reward: {total_reward}")

env.close()
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# argc=5
# argv[0] = --unused
# argv[1] = --background_color_red=0.8745098114013672
# argv[2] = --background_color_green=0.21176470816135406
# argv[3] = --background_color_blue=0.1764705926179886
# argv[4] = --start_demo_name=Physics Server
# ExampleBrowserThreadFunc started
# X11 functions dynamically loaded using dlopen/dlsym OK!
# X11 functions dynamically loaded using dlopen/dlsym OK!
# Creating context
# Created GL 3.3 context
# Direct GLX rendering context obtained
# Making context current
# GL_VENDOR=NVIDIA Corporation
# GL_RENDERER=NVIDIA GeForce RTX 2070 Super with Max-Q Design/PCIe/SSE2
# GL_VERSION=3.3.0 NVIDIA 550.120
# GL_SHADING_LANGUAGE_VERSION=3.30 NVIDIA via Cg compiler
# pthread_getconcurrency()=0
# Version = 3.3.0 NVIDIA 550.120
# Vendor = NVIDIA Corporation
# Renderer = NVIDIA GeForce RTX 2070 Super with Max-Q Design/PCIe/SSE2
# b3Printf: Selected demo: Physics Server
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# MotionThreadFunc thread started
# ven = NVIDIA Corporation
# ven = NVIDIA Corporation
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode 1 - Total Reward: -50.0
# Episode 2 - Total Reward: -50.0
# Episode 3 - Total Reward: -50.0
# Episode 4 - Total Reward: -50.0
# Episode 5 - Total Reward: -50.0
# Episode 6 - Total Reward: -50.0
# Episode 7 - Total Reward: -50.0
# Episode 8 - Total Reward: -50.0
# Episode 9 - Total Reward: -50.0
# Episode 10 - Total Reward: -50.0
# Episode 11 - Total Reward: -50.0
# Episode 12 - Total Reward: -50.0
# Episode 13 - Total Reward: -50.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 25
#      23         env.render()
#      24         total_reward += reward
# ---> 25         time.sleep(0.05)  # Slow down rendering
#      27     print(f"Episode {ep+1} - Total Reward: {total_reward}")
#      29 env.close()
#
# KeyboardInterrupt:

# %%
env.close()
# Out:
# numActiveThreads = 0
# stopping threads
# Thread with taskId 0 exiting
# destroy semaphore
# semaphore destroyed
# Thread TERMINATED
# destroy main semaphore
# main semaphore destroyed
# finished
# numActiveThreads = 0
# btShutDownExampleBrowser stopping threads
# Thread with taskId 0 exiting
# Thread TERMINATED
# destroy semaphore
# semaphore destroyed
# destroy main semaphore
# main semaphore destroyed
